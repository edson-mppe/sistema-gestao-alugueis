# %%
# Liste os seus notebooks na ordem exata de execução
# %run ./1_Baixar_calendarios_OTAs.ipynb

# %%
# %run ./2_Baixar_calendarios_google_sheet.ipynb

# %%
# %run ./3_juntar_calendarios.ipynb

# %%
# %run ./4_verificar_inconsistencias.ipynb

# %%
# %run ./5_atualizar_planilha_google.ipynb

# %%
# %run 6_consolidar_reservas_apartamentos_google_sheet.ipynb

# %%
# %run ./7_salvar_planilha_consolidada.ipynb

# %%
# %run ./8_criar_grafico_html.ipynb

# %%
# %run ./9_buscar_sincronizacoes_automaticas.ipynb
